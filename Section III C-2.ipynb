# %%
import numpy as np 

import matplotlib.pyplot as plt


# This import is needed to modify the way figure behaves
from mpl_toolkits.mplot3d import Axes3D
Axes3D
# %matplotlib inline 

from ipywidgets import *

import pickle_functions as PK
import plot_functions as PL
import helpers as HL

# %load_ext autoreload
import pickle
# %autoreload 2

# %%
folder="SectionC"

# %%
noises=[0.05,0.1,1,3]
colors=[]
Xs=[]
X_2ds=[]
for i, noise in enumerate(noises):
    color,X,X_2d=PK.get_swiss_roll("tsne",folder,modification='_noise'+str(i), create=False, n=1000, noise=noise)
    colors.append(color)
    Xs.append(X)
    X_2ds.append(X_2d)

# %%
fig = plt.figure(figsize=(10,10))
plot=[221, 222,223,224]

for i in range(len(Xs)):
    X=Xs[i]
    ax = fig.add_subplot(220+i+1, projection='3d')
    ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=colors[i], cmap=plt.cm.Spectral)
    ax.set_title('Noise %1.2f' %noises[i])
plt.show()

# %% [markdown]
# # Effect of perplexity:

# %% [markdown]
# ## Noise 0

# %%
p_Z0,per0,p_times0,p_kl_divergence0,p_differences0=PK.perplexity(folder,modification='_noise0',create=False)

# %%
k=0
interactive(PL.plot_inter, Z=fixed(p_Z0), color=fixed(colors[k]),var=fixed(per0),transformation=fixed('t-sne'),
            variable=fixed('per'), i=widgets.IntSlider(min=0,max=len(per0)-1,step=1, value=0),
           error=fixed(p_kl_divergence0),times=fixed(p_times0),difference=fixed(p_differences0)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# ## Noise 1

# %%
p_Z1,per1,p_times1,p_kl_divergence1,p_differences1=PK.perplexity(folder,modification='_noise1',create=False)

# %%
k=1
interactive(PL.plot_inter, Z=fixed(p_Z1), color=fixed(colors[k]),var=fixed(per1),transformation=fixed('t-sne'),
            variable=fixed('per'), i=widgets.IntSlider(min=0,max=len(per1)-1,step=1, value=0),
           error=fixed(p_kl_divergence1),times=fixed(p_times1),difference=fixed(p_differences1)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# ## Noise 2

# %%
p_Z2,per2,p_times2,p_kl_divergence2,p_differences2=PK.perplexity(folder,modification='_noise2',create=False)

# %%
k=2
interactive(PL.plot_inter, Z=fixed(p_Z2), color=fixed(colors[k]),var=fixed(per2),transformation=fixed('t-sne'),
            variable=fixed('per'), i=widgets.IntSlider(min=0,max=len(per2)-1,step=1, value=0),
           error=fixed(p_kl_divergence2),times=fixed(p_times2),difference=fixed(p_differences2)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# ## Noise 3

# %%
p_Z3,per3,p_times3,p_kl_divergence3,p_differences3=PK.perplexity(folder,modification='_noise3',create=False)

# %%
k=3
interactive(PL.plot_inter, Z=fixed(p_Z3), color=fixed(colors[k]),var=fixed(per3),transformation=fixed('t-sne'),
            variable=fixed('per'), i=widgets.IntSlider(min=0,max=len(per3)-1,step=1, value=0),
           error=fixed(p_kl_divergence3),times=fixed(p_times3),difference=fixed(p_differences3)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# # Effect of early exxaggeration:

# %% [markdown]
# ## Noise 0

# %%
e_Z0,early_exaggeration0,e_times0,e_kl_divergence0,e_differences0=PK.early_exxaggeration(folder,modification='_noise0',create=False)

# %%
k=0
interactive(PL.plot_inter, Z=fixed(e_Z0), color=fixed(colors[k]),var=fixed(early_exaggeration0),transformation=fixed('t-sne'),
            variable=fixed('early_exaggeration'), i=widgets.IntSlider(min=0,max=len(early_exaggeration0)-1,step=1,value=0),
           error=fixed(e_kl_divergence0),times=fixed(e_times0),difference=fixed(e_differences0)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# ## Noise 1

# %%
e_Z1,early_exaggeration1,e_times1,e_kl_divergence1,e_differences1=PK.early_exxaggeration(folder,modification='_noise1',create=False)

# %%
k=1
interactive(PL.plot_inter, Z=fixed(e_Z1), color=fixed(colors[k]),var=fixed(early_exaggeration1),transformation=fixed('t-sne'),
            variable=fixed('early_exaggeration'), i=widgets.IntSlider(min=0,max=len(early_exaggeration1)-1,step=1,value=0),
           error=fixed(e_kl_divergence1),times=fixed(e_times1),difference=fixed(e_differences1)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# ## Noise 2

# %%
e_Z2,early_exaggeration2,e_times2,e_kl_divergence2,e_differences2=PK.early_exxaggeration(folder,modification='_noise2',create=False)

# %%
k=2
interactive(PL.plot_inter, Z=fixed(e_Z2), color=fixed(colors[k]),var=fixed(early_exaggeration2),transformation=fixed('t-sne'),
            variable=fixed('early_exaggeration'), i=widgets.IntSlider(min=0,max=len(early_exaggeration2)-1,step=1,value=0),
           error=fixed(e_kl_divergence2),times=fixed(e_times2),difference=fixed(e_differences2)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# ## Noise 3

# %%
e_Z3,early_exaggeration3,e_times3,e_kl_divergence3,e_differences3=PK.early_exxaggeration(folder,modification='_noise3',create=False)

# %%
k=3
interactive(PL.plot_inter, Z=fixed(e_Z3), color=fixed(colors[k]),var=fixed(early_exaggeration3),transformation=fixed('t-sne'),
            variable=fixed('early_exaggeration'), i=widgets.IntSlider(min=0,max=len(early_exaggeration3)-1,step=1,value=0),
           error=fixed(e_kl_divergence3),times=fixed(e_times3),difference=fixed(e_differences3)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# # Effect of learning rate:

# %% [markdown]
# ## Noise 0

# %%
l_Z0,learning_rates0,l_times0,l_kl_divergence0,l_differences0=PK.learning_rates(folder,modification='_noise0', create=False)

# %%
k=0
interactive(PL.plot_inter, transformation=fixed('t-sne'), Z=fixed(l_Z0), color=fixed(colors[k]),
            var=fixed(learning_rates0),variable=fixed('learning_rate'), 
            i=widgets.IntSlider(min=0,max=len(learning_rates0)-1,step=1, value=0),
           error=fixed(l_kl_divergence0),times=fixed(l_times0),difference=fixed(l_differences0)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# ## Noise 1

# %%
l_Z1,learning_rates1,l_times1,l_kl_divergence1,l_differences1=PK.learning_rates(folder,modification='_noise1', create=False)

# %%
k=1
interactive(PL.plot_inter, transformation=fixed('t-sne'), Z=fixed(l_Z1), color=fixed(colors[k]),
            var=fixed(learning_rates1),variable=fixed('learning_rate'), 
            i=widgets.IntSlider(min=0,max=len(learning_rates1)-1,step=1, value=0),
           error=fixed(l_kl_divergence1),times=fixed(l_times1),difference=fixed(l_differences1)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# ## Noise 2

# %%
l_Z2,learning_rates2,l_times2,l_kl_divergence2,l_differences2=PK.learning_rates(folder,modification='_noise2', create=False)

# %%
k=2
interactive(PL.plot_inter, transformation=fixed('t-sne'), Z=fixed(l_Z2), color=fixed(colors[k]),
            var=fixed(learning_rates2),variable=fixed('learning_rate'), 
            i=widgets.IntSlider(min=0,max=len(learning_rates2)-1,step=1, value=0),
           error=fixed(l_kl_divergence2),times=fixed(l_times2),difference=fixed(l_differences2)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# ## Noise 3

# %%
l_Z3,learning_rates3,l_times3,l_kl_divergence3,l_differences3=PK.learning_rates(folder,modification='_noise3', create=False)

# %%
k=3
interactive(PL.plot_inter, transformation=fixed('t-sne'), Z=fixed(l_Z3), color=fixed(colors[k]),
            var=fixed(learning_rates3),variable=fixed('learning_rate'), 
            i=widgets.IntSlider(min=0,max=len(learning_rates3)-1,step=1, value=0),
           error=fixed(l_kl_divergence3),times=fixed(l_times3),difference=fixed(l_differences3)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# # Effect of threshold:

# %% [markdown]
# ## Noise 0

# %%
 t_Z0,threshold0,t_times0,t_kl_divergence0,t_differences0=PK.threshold(folder, modification='_noise0',create=False)

# %%
k=0
interactive(PL.plot_inter,transformation=fixed('t-sne'), Z=fixed(t_Z0), color=fixed(colors[k]),var=fixed(threshold0)
            ,variable=fixed('threshold'), i=widgets.IntSlider(min=0,max=len(threshold0)-1,step=1, value=0),
           error=fixed(t_kl_divergence0),times=fixed(t_times0),difference=fixed(t_differences0)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# ## Noise 1

# %%
 t_Z1,threshold1,t_times1,t_kl_divergence1,t_differences1=PK.threshold(folder, modification='_noise1',create=False)

# %%
k=1
interactive(PL.plot_inter,transformation=fixed('t-sne'), Z=fixed(t_Z1), color=fixed(colors[k]),var=fixed(threshold1)
            ,variable=fixed('threshold'), i=widgets.IntSlider(min=0,max=len(threshold1)-1,step=1, value=0),
           error=fixed(t_kl_divergence1),times=fixed(t_times1),difference=fixed(t_differences1)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# ## Noise 2

# %%
 t_Z2,threshold2,t_times2,t_kl_divergence2,t_differences2=PK.threshold(folder, modification='_noise2',create=False)

# %%
k=2
interactive(PL.plot_inter,transformation=fixed('t-sne'), Z=fixed(t_Z2), color=fixed(colors[k]),var=fixed(threshold2)
            ,variable=fixed('threshold'), i=widgets.IntSlider(min=0,max=len(threshold2)-1,step=1, value=0),
           error=fixed(t_kl_divergence2),times=fixed(t_times2),difference=fixed(t_differences2)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %% [markdown]
# ## Noise 3

# %%
 t_Z3,threshold3,t_times3,t_kl_divergence3,t_differences3=PK.threshold(folder, modification='_noise3',create=False)

# %%
k=3
interactive(PL.plot_inter,transformation=fixed('t-sne'), Z=fixed(t_Z3), color=fixed(colors[k]),var=fixed(threshold3)
            ,variable=fixed('threshold'), i=widgets.IntSlider(min=0,max=len(threshold3)-1,step=1, value=0),
           error=fixed(t_kl_divergence3),times=fixed(t_times3),difference=fixed(t_differences3)
           ,error_type=fixed('KL divergence'))
# Out:
# /Users/HeddaVik/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py:567: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)
